# %% [markdown]
# <a href="https://colab.research.google.com/github/cdavin2/dsp_hw/blob/main/hw6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd

# make sure the plot is displayed in this notebook
# %matplotlib inline
# specify the size of the plot
plt.rcParams['figure.figsize'] = (16, 6)

# for auto-reloading extenrnal modules
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Case 1

# %%
N = 20
w1 = .62831853
a = 0
w2 = 0
b = 0
n = np.linspace(0, N-1, N)

dn = np.random.default_rng().normal(0, 1, size=N)
xn = (np.cos(w1*n) + a * np.cos(w2*n) + b*dn)

plt.ylabel("xn for Case 1")
plt.xlabel("n")
plt.stem(n, xn)
# Out:
# <StemContainer object of 3 artists>

# %%
N = 20
w1 = .62831853
a = 0
w2 = 0
b = 0
n = np.linspace(0, N-1, N)

dn = np.random.default_rng().normal(0, 1, size=N)
xn = (np.cos(w1*n) + a * np.cos(w2*n) + b*dn)
xn_fft = np.fft.fft(xn.astype(complex))


plt.ylabel("Magnitude of DFT of Case 1")
plt.xlabel("k")
plt.stem(np.abs(xn_fft))
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# Case 2

# %%
N = 200
w1 = .62831853
a = 0
w2 = 0
b = 0
n = np.linspace(0, N-1, N)

dn = np.random.default_rng().normal(0, 1, size=N)
xn = (np.cos(w1*n) + a * np.cos(w2*n) + b*dn)

plt.ylabel("xn for Case 2")
plt.xlabel("n")
plt.stem(n, xn)
# Out:
# <StemContainer object of 3 artists>

# %%
N = 200
w1 = .62831853
a = 0
w2 = 0
b = 0
n = np.linspace(0, N-1, N)

dn = np.random.default_rng().normal(0, 1, size=N)
xn = (np.cos(w1*n) + a * np.cos(w2*n) + b*dn)
xn_fft = np.fft.fft(xn.astype(complex))


plt.ylabel("Magnitude of DFT of Case 2")
plt.xlabel("k")
plt.stem(np.abs(xn_fft))
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# Case 3

# %%
N = 20
w1 = .64402649
a = 0
w2 = 0
b = 0
n = np.linspace(0, N-1, N)

dn = np.random.default_rng().normal(0, 1, size=N)
xn = (np.cos(w1*n) + a * np.cos(w2*n) + b*dn)

plt.ylabel("xn for Case 3")
plt.xlabel("n")
plt.stem(n, xn)
# Out:
# <StemContainer object of 3 artists>

# %%
N = 20
w1 = .64402649
a = 0
w2 = 0
b = 0
n = np.linspace(0, N-1, N)

dn = np.random.default_rng().normal(0, 1, size=N)
xn = (np.cos(w1*n) + a * np.cos(w2*n) + b*dn)
xn_fft = np.fft.fft(xn.astype(complex))


plt.ylabel("Magnitude of DFT of Case 3")
plt.xlabel("k")
plt.stem(np.abs(xn_fft))
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# Case 4

# %%
N = 200
w1 = .64402649
a = 0
w2 = 0
b = 0
n = np.linspace(0, N-1, N)

dn = np.random.default_rng().normal(0, 1, size=N)
xn = (np.cos(w1*n) + a * np.cos(w2*n) + b*dn)

plt.ylabel("xn for Case 4")
plt.xlabel("n")
plt.stem(n, xn)
# Out:
# <StemContainer object of 3 artists>

# %%
N = 200
w1 = .64402649
a = 0
w2 = 0
b = 0
n = np.linspace(0, N-1, N)

dn = np.random.default_rng().normal(0, 1, size=N)
xn = (np.cos(w1*n) + a * np.cos(w2*n) + b*dn)
xn_fft = np.fft.fft(xn.astype(complex))


plt.ylabel("Magnitude of DFT of Case 4")
plt.xlabel("k")
plt.stem(np.abs(xn_fft))
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# Case 5

# %%
N = 200
w1 = .64402649
a = .4
w2 = 1.27234502
b = 0
n = np.linspace(0, N-1, N)

dn = np.random.default_rng().normal(0, 1, size=N)
xn = (np.cos(w1*n) + a * np.cos(w2*n) + b*dn)

plt.ylabel("xn for Case 5")
plt.xlabel("n")
plt.stem(n, xn)
# Out:
# <StemContainer object of 3 artists>

# %%
N = 200
w1 = .64402649
a = .4
w2 = 1.27234502
b = 0
n = np.linspace(0, N-1, N)

dn = np.random.default_rng().normal(0, 1, size=N)
xn = (np.cos(w1*n) + a * np.cos(w2*n) + b*dn)
xn_fft = np.fft.fft(xn.astype(complex))

plt.ylabel("Magnitude of DFT of Case 5")
plt.xlabel("k")
plt.stem(np.abs(xn_fft))
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# Case 6

# %%
N = 200
w1 = .64402649
a = .4
w2 = 0.79168135
b = 0
n = np.linspace(0, N-1, N)

dn = np.random.default_rng().normal(0, 1, size=N)
xn = (np.cos(w1*n) + a * np.cos(w2*n) + b*dn)

plt.ylabel("xn for Case 6")
plt.xlabel("n")
plt.stem(n, xn)
# Out:
# <StemContainer object of 3 artists>

# %%
N = 200
w1 = .64402649
a = .4
w2 = 0.79168135
b = 0
n = np.linspace(0, N-1, N)

dn = np.random.default_rng().normal(0, 1, size=N)
xn = (np.cos(w1*n) + a * np.cos(w2*n) + b*dn)
xn_fft = np.fft.fft(xn.astype(complex))

plt.ylabel("Magnitude of DFT of Case 6")
plt.xlabel("k")
plt.stem(np.abs(xn_fft))
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# Case 7

# %%
N = 200
w1 = .64402649
a = .4
w2 = 0.79168135
b = .2
n = np.linspace(0, N-1, N)

dn = np.random.default_rng().normal(0, 1, size=N)
xn = (np.cos(w1*n) + a * np.cos(w2*n) + b*dn)

plt.ylabel("xn for Case 7")
plt.xlabel("n")
plt.stem(n, xn)
# Out:
# <StemContainer object of 3 artists>

# %%
N = 200
w1 = .64402649
a = .4
w2 = 0.79168135
b = .2
n = np.linspace(0, N-1, N)

dn = np.random.default_rng().normal(0, 1, size=N)
xn = (np.cos(w1*n) + a * np.cos(w2*n) + b*dn)
xn_fft = np.fft.fft(xn.astype(complex))

plt.ylabel("Magnitude of DFT of Case 7")
plt.xlabel("k")
plt.stem(np.abs(xn_fft))
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# Case 8

# %%
N = 200
w1 = .64402649
a = .4
w2 = 0.79168135
b = 1
n = np.linspace(0, N-1, N)

dn = np.random.default_rng().normal(0, 1, size=N)
xn = (np.cos(w1*n) + a * np.cos(w2*n) + b*dn)

plt.ylabel("xn for Case 8")
plt.xlabel("n")
plt.stem(n, xn)
# Out:
# <StemContainer object of 3 artists>

# %%
N = 200
w1 = .64402649
a = .4
w2 = 0.79168135
b = 1
n = np.linspace(0, N-1, N)

dn = np.random.default_rng().normal(0, 1, size=N)
xn = (np.cos(w1*n) + a * np.cos(w2*n) + b*dn)
xn_fft = np.fft.fft(xn.astype(complex))

plt.ylabel("Magnitude of DFT of Case 8")
plt.xlabel("k")
plt.stem(np.abs(xn_fft))
# Out:
# <StemContainer object of 3 artists>
