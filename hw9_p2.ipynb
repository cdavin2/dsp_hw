# %% [markdown]
# <a href="https://colab.research.google.com/github/cdavin2/dsp_hw/blob/main/hw9_p2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd

# make sure the plot is displayed in this notebook
# %matplotlib inline
# specify the size of the plot
plt.rcParams['figure.figsize'] = (16, 6)

# for auto-reloading extenrnal modules
# %load_ext autoreload
# %autoreload 2

# %%
y0 = 0
yp0 = []
yp0.append(y0)

y1 = 0
yp1 = []
yp1.append(y1)

x1 = 0
xp1 = []

slope = 1

i = 1
while np.abs(slope) > 10 ** -4:
  x1 = (y0 + y1) / 2
  y0 = 3*x1/4
  y1 = (3*(x1 + 3)*(x1**2 + 9))/(4*(x1**2 + 3*x1 + 9))
  
  yp0.append(y0)
  yp1.append(y1)
  xp1.append(x1)

  slope = yp1[i] - yp1[i-1]
  i = i + 1

print(x1) # approx the same as problem 1
# Out:
# 2.0740027643739065

# %%
plt.ylabel("x1")
plt.xlabel("indices")
plt.plot(xp1)

# %%
plt.ylabel("y0")
plt.xlabel("indices")
plt.plot(yp0)

# %%
plt.ylabel("y1")
plt.xlabel("indices")
plt.plot(yp1)
