# %% [markdown]
# <a href="https://colab.research.google.com/github/cdavin2/dsp_hw/blob/main/hw9_p3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd

# make sure the plot is displayed in this notebook
# %matplotlib inline
# specify the size of the plot
plt.rcParams['figure.figsize'] = (16, 6)

# for auto-reloading extenrnal modules
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
X_50 = np.random.uniform(0, 3, size = 50)
fXx_50 = (1/9 * X_50**2)
plt.hist(fXx_50, bins = 10)
# Out:
# (array([12.,  9.,  5.,  2.,  7.,  2.,  3.,  3.,  1.,  6.]),
#  array([6.27608203e-04, 1.00480824e-01, 2.00334040e-01, 3.00187255e-01,
#         4.00040471e-01, 4.99893686e-01, 5.99746902e-01, 6.99600118e-01,
#         7.99453333e-01, 8.99306549e-01, 9.99159765e-01]),
#  <BarContainer object of 10 artists>)

# %%
X_500 = np.random.uniform(0, 3, size = 500)
fXx_500 = (1/9 * X_500**2)
plt.hist(fXx_500, bins = 10)
# Out:
# (array([170.,  52.,  55.,  45.,  34.,  22.,  34.,  29.,  25.,  34.]),
#  array([5.82393706e-05, 9.99261510e-02, 1.99794063e-01, 2.99661974e-01,
#         3.99529886e-01, 4.99397798e-01, 5.99265709e-01, 6.99133621e-01,
#         7.99001533e-01, 8.98869444e-01, 9.98737356e-01]),
#  <BarContainer object of 10 artists>)

# %%
X_5000 = np.random.uniform(0, 3, size = 5000)
fXx_5000 = (1/9 * X_5000**2)
plt.hist(fXx_5000, bins = 10)
# Out:
# (array([1561.,  675.,  504.,  474.,  363.,  324.,  298.,  282.,  262.,
#          257.]),
#  array([2.38107543e-07, 9.98991180e-02, 1.99797998e-01, 2.99696878e-01,
#         3.99595757e-01, 4.99494637e-01, 5.99393517e-01, 6.99292397e-01,
#         7.99191277e-01, 8.99090157e-01, 9.98989037e-01]),
#  <BarContainer object of 10 artists>)

# %%
X_50000 = np.random.uniform(0, 3, size = 50000)
fXx_50000 = (1/9 * X_50000**2)
plt.hist(fXx_50000, bins = 10)
# Out:
# (array([15909.,  6575.,  5094.,  4372.,  3718.,  3311.,  3060.,  2803.,
#          2670.,  2488.]),
#  array([3.31796989e-13, 9.99972349e-02, 1.99994470e-01, 2.99991705e-01,
#         3.99988940e-01, 4.99986175e-01, 5.99983409e-01, 6.99980644e-01,
#         7.99977879e-01, 8.99975114e-01, 9.99972349e-01]),
#  <BarContainer object of 10 artists>)
