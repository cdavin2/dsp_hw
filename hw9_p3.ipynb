# %% [markdown]
# <a href="https://colab.research.google.com/github/cdavin2/dsp_hw/blob/main/hw9_p3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd

# make sure the plot is displayed in this notebook
# %matplotlib inline
# specify the size of the plot
plt.rcParams['figure.figsize'] = (16, 6)

# for auto-reloading extenrnal modules
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Part A

# %%
SX_50000 = np.linspace(0, 3, 50000)
SY_50000 = np.linspace(0, 1, 50000)
fXx_50000 = 1/9 * (SX_50000**2)
FXx_50000 = 1/27 * (SX_50000**3)
theta_50000 = 3 * SY_50000**(1/3)

# %%
plt.ylabel("fX(x)")
plt.xlabel("Samples")
plt.plot(SX_50000, fXx_50000)

# %%
plt.ylabel("FX(x)")
plt.xlabel("Samples")
plt.plot(SX_50000, FXx_50000)

# %%
plt.ylabel("Theta(u)")
plt.xlabel("Samples")
plt.plot(SY_50000, theta_50000)

# %% [markdown]
# Part B

# %%
U_50 = np.random.uniform(0, 1, size = 50)
X_50 = 3 * U_50**(1/3) ## fXx
plt.ylabel("Frequency")
plt.xlabel("X")
plt.plot(SX_50000, fXx_50000)
plt.hist(X_50, bins = 10, density = True);

# %%
U_500 = np.random.uniform(0, 1, size = 500)
X_500 = 3 * U_500**(1/3) ## FXx
plt.ylabel("Frequency")
plt.xlabel("X")
plt.plot(SX_50000, fXx_50000)
plt.hist(X_500, bins = 50, density = True);

# %%
U_5000 = np.random.uniform(0, 1, size = 5000)
X_5000 = 3 * U_5000**(1/3) ## FXx
plt.ylabel("Frequency")
plt.xlabel("X")
plt.plot(SX_50000, fXx_50000)
plt.hist(X_5000, bins = 100, density = True);

# %%
U_50000 = np.random.uniform(0, 1, size = 50000)
X_50000 = (3 * U_50000**(1/3)) ## FXx
plt.ylabel("Frequency")
plt.xlabel("X")
plt.plot(SX_50000, fXx_50000)
plt.hist(X_50000, bins = 150, density = True);
plt.show()

# %% [markdown]
# The more data points used, the more accurate the density function in Eq. (1-1) is displayed in the histogram.

# %% [markdown]
# Part C

# %%
U_50000 = np.random.uniform(0, 1, size = 50000)
X_50000 = 3 * U_50000**(1/3) ## fXx
quant = []

for i in range(len(X_50000)):
  if X_50000[i] < 1.5:
    quant.append(.75)
  else:
    quant.append(2.25)

error = np.sum( (quant-X_50000)**2 ) / 50000
print(error)
# Out:
# 0.1975329990202675

# %% [markdown]
# Part D

# %%
U_50000 = np.random.uniform(0, 1, size = 50000)
X_50000 = 3 * U_50000**(1/3) ## fXx
quant = []

for i in range(len(X_50000)):
  if X_50000[i] < 2.07:
    quant.append(1.55)
  else:
    quant.append(2.59)

error = np.sum( (quant-X_50000)**2 ) / 50000
print(error)
# Out:
# 0.0991627888804752

# %% [markdown]
# The rms error of the quantizer with optimal values is less than the rms error of the quantizer with non-optimal values. This  makes sense as we would expect a lower error when using optimal values compared when not.
